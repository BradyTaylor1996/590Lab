# %% [markdown]
# import argparse
# import os, sys
# import time
# import datetime
# import matplotlib.pyplot as plt
#
# # Import pytorch dependencies
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torchvision
# import torchvision.transforms as transforms
# import torch.optim as optim
# from tqdm import tqdm_notebook as tqdm
#
# # You cannot change this line.
# from tools.dataloader import CIFAR10

# %%
""" 
Assignment 2(a)
Build the LeNet-5 model by following table 1 or figure 1.

You can also insert batch normalization and leave the LeNet-5 
with batch normalization here for assignment 3(c).
"""
# Create the neural network module: LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.bn1 = nn.BatchNorm2d(6, eps=1e-05, momentum=0.9)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.bn2 = nn.BatchNorm2d(16, eps=1e-05, momentum=0.9)
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        
    def forward(self, x):
        # output = F.relu(self.conv1(x))
        output = F.relu(self.bn1(self.conv1(x)))
        output = F.max_pool2d(output, 2) 
        # output = F.relu(self.conv2(output))
        output = F.relu(self.bn2(self.conv2(output)))
        output = F.max_pool2d(output,2)
        output = output.view(output.size(0), -1)
        output = F.relu(self.fc1(output))
        output = F.relu(self.fc2(output))
        output = self.fc3(output)
        return output

# %%
"""
Hyperparameter optimization in assignment 4(a), 4(b) can be 
conducted here.
Be sure to leave only your best hyperparameter combination
here and comment the original hyperparameter settings.
"""

# Setting some hyperparameters
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
INITIAL_LR = 0.02 # 0.01
MOMENTUM = 0.9 
REG = 5e-4 # 1e-4
EPOCHS = 50 # 30
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %% [markdown]
# **Your answer:**

# %%
"""
Assignment 2(b)
Write functions to load dataset and preprocess the incoming data. 
We recommend that the preprocess scheme \textbf{must} include 
normalize, standardization, batch shuffling to make sure the training 
process goes smoothly. 
The preprocess scheme may also contain some data augmentation methods 
(e.g., random crop, random flip, etc.). 

Reference value for mean/std:

mean(RGB-format): (0.4914, 0.4822, 0.4465)
std(RGB-format): (0.2023, 0.1994, 0.2010)


NOTE: Considering this process has strong corrlelation with assignment 3(b), 
please leave the data preprocessing method which can achieve the highest 
validation accuracy here. You can include your original data augmentation
method as comments and denotes the accuracy difference between thest two 
methods.
"""
# Specify preprocessing function.
# Reference mean/std value for 
transform_train = transforms.Compose([
    # transforms.ColorJitter(brightness=2),
    transforms.RandomCrop(32, 4),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# %% [markdown]
# **Your answer:**

# %%
# Call the dataset Loader
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=1)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=1)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = False
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# [Errno 2] No such file or directory: './saved_model/model.h5'
# Checkpoint not found.
# Training from scratch ...
# Starting from learning rate 0.020000:

# %%
"""
Assignment 2(c)
In the targeted classification task, we use cross entropy loss with L2 
regularization as the learning object.
You need to formulate the cross-entropy loss function in PyTorch.
You should also specify a PyTorch Optimizer to optimize this loss function.
We recommend you to use the SGD-momentum with an initial learning rate 0.01 
and momentum 0.9 as a start.
"""
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), INITIAL_LR, MOMENTUM, REG)

# %%
"""
Assignment 3(a)
Start the training process over the whole CIFAR-10 training dataset. 
For sanity check, you are required to report the initial loss value at 
the beginning of the training process and briefly justify this value. 
Run the training process for \textbf{a maximum of 30} epochs and you 
should be able to reach around \textbf{65\%} accuracy on the validation 
dataset.
"""
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0
training_accuracies = []
validation_accuracies = []
my_flag = 0

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        if my_flag == 0:
            print("Initial loss: %.4f" %(loss))
            my_flag = 1
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        # Calculate accuracy
        total_examples += len(outputs)
        correct_examples += predicted.eq(targets).sum().item()

        train_loss += loss

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    training_accuracies.append(avg_acc)
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            # Calculate accuracy
            total_examples += len(outputs)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    validation_accuracies.append(avg_acc)
        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
    DECAY_EPOCHS = 2
    DECAY = 0.98
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate*DECAY
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
all_epochs = list(range(EPOCHS))
plt.plot(all_epochs, training_accuracies, label = 'Training Accuracy')
plt.plot(all_epochs, validation_accuracies, label = 'Validation Accuracy')
plt.ylim(0,1)
plt.xlim(0,29)
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# 2019-09-27 21:05:09.364041
# Epoch 0:
# 352
# Initial loss: 2.3042
# Training loss: 1.7714, Training accuracy: 0.3442
# 2019-09-27 21:05:23.154357
# Validation...
# Validation loss: 1.4456, Validation accuracy: 0.4628
# Saving ...
# 2019-09-27 21:05:24.378610
# Epoch 1:
# 352
# Training loss: 1.4582, Training accuracy: 0.4683
# 2019-09-27 21:05:37.687079
# Validation...
# Validation loss: 1.2878, Validation accuracy: 0.5284
# Saving ...
# 2019-09-27 21:05:38.969981
# Epoch 2:
# 352
# Training loss: 1.3350, Training accuracy: 0.5250
# 2019-09-27 21:05:50.854799
# Validation...
# Validation loss: 1.2809, Validation accuracy: 0.5474
# Current learning rate has decayed to 0.019600
# Saving ...
# 2019-09-27 21:05:52.106193
# Epoch 3:
# 352
# Training loss: 1.2609, Training accuracy: 0.5532
# 2019-09-27 21:06:04.631032
# Validation...
# Validation loss: 1.1644, Validation accuracy: 0.5858
# Saving ...
# 2019-09-27 21:06:05.729672
# Epoch 4:
# 352
# Training loss: 1.2039, Training accuracy: 0.5711
# 2019-09-27 21:06:17.207427
# Validation...
# Validation loss: 1.1423, Validation accuracy: 0.5894
# Current learning rate has decayed to 0.019208
# Saving ...
# 2019-09-27 21:06:18.314355
# Epoch 5:
# 352
# Training loss: 1.1702, Training accuracy: 0.5816
# 2019-09-27 21:06:29.761416
# Validation...
# Validation loss: 1.0841, Validation accuracy: 0.6144
# Saving ...
# 2019-09-27 21:06:30.847068
# Epoch 6:
# 352
# Training loss: 1.1437, Training accuracy: 0.5965
# 2019-09-27 21:06:42.399546
# Validation...
# Validation loss: 1.0642, Validation accuracy: 0.6250
# Current learning rate has decayed to 0.018824
# Saving ...
# 2019-09-27 21:06:43.657806
# Epoch 7:
# 352
# Training loss: 1.1178, Training accuracy: 0.6034
# 2019-09-27 21:06:55.377288
# Validation...
# Validation loss: 1.0538, Validation accuracy: 0.6274
# Saving ...
# 2019-09-27 21:06:56.498462
# Epoch 8:
# 352
# Training loss: 1.0974, Training accuracy: 0.6129
# 2019-09-27 21:07:07.892973
# Validation...
# Validation loss: 0.9981, Validation accuracy: 0.6434
# Current learning rate has decayed to 0.018447
# Saving ...
# 2019-09-27 21:07:08.978280
# Epoch 9:
# 352
# Training loss: 1.0812, Training accuracy: 0.6186
# 2019-09-27 21:07:20.432992
# Validation...
# Validation loss: 1.0587, Validation accuracy: 0.6252
# 2019-09-27 21:07:21.520974
# Epoch 10:
# 352
# Training loss: 1.0647, Training accuracy: 0.6261
# 2019-09-27 21:07:33.242591
# Validation...
# Validation loss: 0.9984, Validation accuracy: 0.6454
# Current learning rate has decayed to 0.018078
# Saving ...
# 2019-09-27 21:07:34.383727
# Epoch 11:
# 352
# Training loss: 1.0418, Training accuracy: 0.6311
# 2019-09-27 21:07:46.276513
# Validation...
# Validation loss: 1.0169, Validation accuracy: 0.6326
# 2019-09-27 21:07:47.364990
# Epoch 12:
# 352
# Training loss: 1.0347, Training accuracy: 0.6365
# 2019-09-27 21:07:58.912959
# Validation...
# Validation loss: 1.0006, Validation accuracy: 0.6466
# Current learning rate has decayed to 0.017717
# Saving ...
# 2019-09-27 21:08:00.031099
# Epoch 13:
# 352
# Training loss: 1.0206, Training accuracy: 0.6403
# 2019-09-27 21:08:12.032895
# Validation...
# Validation loss: 0.9640, Validation accuracy: 0.6648
# Saving ...
# 2019-09-27 21:08:13.170338
# Epoch 14:
# 352
# Training loss: 1.0108, Training accuracy: 0.6440
# 2019-09-27 21:08:24.627672
# Validation...
# Validation loss: 0.9595, Validation accuracy: 0.6618
# Current learning rate has decayed to 0.017363
# 2019-09-27 21:08:25.723137
# Epoch 15:
# 352
# Training loss: 1.0053, Training accuracy: 0.6410
# 2019-09-27 21:08:38.139226
# Validation...
# Validation loss: 0.9615, Validation accuracy: 0.6664
# Saving ...
# 2019-09-27 21:08:39.253566
# Epoch 16:
# 352
# Training loss: 0.9826, Training accuracy: 0.6520
# 2019-09-27 21:08:51.312229
# Validation...
# Validation loss: 0.9551, Validation accuracy: 0.6674
# Current learning rate has decayed to 0.017015
# Saving ...
# 2019-09-27 21:08:52.420048
# Epoch 17:
# 352
# Training loss: 0.9813, Training accuracy: 0.6522
# 2019-09-27 21:09:04.360970
# Validation...
# Validation loss: 0.9734, Validation accuracy: 0.6550
# 2019-09-27 21:09:05.523675
# Epoch 18:
# 352
# Training loss: 0.9725, Training accuracy: 0.6562
# 2019-09-27 21:09:17.385526
# Validation...
# Validation loss: 0.9580, Validation accuracy: 0.6612
# Current learning rate has decayed to 0.016675
# 2019-09-27 21:09:18.503114
# Epoch 19:
# 352
# Training loss: 0.9670, Training accuracy: 0.6582
# 2019-09-27 21:09:30.537791
# Validation...
# Validation loss: 0.9346, Validation accuracy: 0.6624
# 2019-09-27 21:09:31.679610
# Epoch 20:
# 352
# Training loss: 0.9530, Training accuracy: 0.6640
# 2019-09-27 21:09:44.263367
# Validation...
# Validation loss: 0.9461, Validation accuracy: 0.6740
# Current learning rate has decayed to 0.016341
# 2019-09-27 21:13:01.540998
# Validation...
# Validation loss: 0.8823, Validation accuracy: 0.6900
# Saving ...
# 2019-09-27 21:13:02.837383
# Epoch 36:
# 352
# Training loss: 0.8866, Training accuracy: 0.6891
# 2019-09-27 21:13:14.656977
# Validation...
# Validation loss: 0.8871, Validation accuracy: 0.6920
# Current learning rate has decayed to 0.013903
# Saving ...
# 2019-09-27 21:13:15.773755
# Epoch 37:
# 352
# Training loss: 0.8809, Training accuracy: 0.6894
# 2019-09-27 21:13:27.721314
# Validation...
# Validation loss: 0.9039, Validation accuracy: 0.6886
# 2019-09-27 21:13:28.824996
# Epoch 38:
# 352
# Training loss: 0.8758, Training accuracy: 0.6892
# 2019-09-27 21:13:40.677735
# Validation...
# Validation loss: 0.9007, Validation accuracy: 0.6858
# Current learning rate has decayed to 0.013625
# 2019-09-27 21:13:41.778072
# Epoch 39:
# 352
# Training loss: 0.8730, Training accuracy: 0.6892
# 2019-09-27 21:13:53.537914
# Validation...
# Validation loss: 0.8643, Validation accuracy: 0.7000
# Saving ...
# 2019-09-27 21:13:54.619127
# Epoch 40:
# 352
# Training loss: 0.8722, Training accuracy: 0.6909
# 2019-09-27 21:14:06.600974
# Validation...
# Validation loss: 0.8565, Validation accuracy: 0.6972
# Current learning rate has decayed to 0.013352
# 2019-09-27 21:14:07.693023
# Epoch 41:
# 352
# Training loss: 0.8692, Training accuracy: 0.6936
# 2019-09-27 21:14:19.902298
# Validation...
# Validation loss: 0.8722, Validation accuracy: 0.6962
# 2019-09-27 21:14:21.069395
# Epoch 42:
# 352
# Training loss: 0.8633, Training accuracy: 0.6935
# 2019-09-27 21:14:32.983796
# Validation...
# Validation loss: 0.8718, Validation accuracy: 0.6912
# Current learning rate has decayed to 0.013085
# 2019-09-27 21:14:34.117023
# Epoch 43:
# 352
# Training loss: 0.8608, Training accuracy: 0.6956
# 2019-09-27 21:14:45.908701
# Validation...
# Validation loss: 0.8821, Validation accuracy: 0.6918
# 2019-09-27 21:14:47.203159
# Epoch 44:
# 352
# Training loss: 0.8586, Training accuracy: 0.6955
# 2019-09-27 21:14:59.205987
# Validation...
# Validation loss: 0.8557, Validation accuracy: 0.6974
# Current learning rate has decayed to 0.012823
# 2019-09-27 21:15:00.333515
# Epoch 45:
# 352
# Training loss: 0.8547, Training accuracy: 0.6970
# 2019-09-27 21:15:12.117041
# Validation...
# Validation loss: 0.8569, Validation accuracy: 0.6992
# 2019-09-27 21:15:13.236218
# Epoch 46:
# 352
# Training loss: 0.8552, Training accuracy: 0.6971
# 2019-09-27 21:15:25.207573
# Validation...
# Validation loss: 0.8508, Validation accuracy: 0.7080
# Current learning rate has decayed to 0.012567
# Saving ...
# 2019-09-27 21:15:26.295782
# Epoch 47:
# 352
# Training loss: 0.8457, Training accuracy: 0.6969
# 2019-09-27 21:15:38.960983
# Validation...
# Validation loss: 0.8631, Validation accuracy: 0.7008
# 2019-09-27 21:15:40.015081
# Epoch 48:
# 352
# Training loss: 0.8514, Training accuracy: 0.6995
# 2019-09-27 21:15:51.931623
# Validation...
# Validation loss: 0.8532, Validation accuracy: 0.7010
# Current learning rate has decayed to 0.012316
# 2019-09-27 21:15:53.017015
# Epoch 49:
# 352
# Training loss: 0.8423, Training accuracy: 0.7047
# 2019-09-27 21:16:04.836965
# Validation...
# Validation loss: 0.8628, Validation accuracy: 0.6998
# Optimization finished.
